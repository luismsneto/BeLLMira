# %%
import bellmira

# %%
from bellmira.llm_model.llm_model_client import ModelClient

model = ModelClient(base_url= "https://millmchatqwen2-backend.dat-aip-millm.in.mbcp.cloud/")
req = model.build_chat_request(
    user_prompt="Who are you?",
    system_prompt="",
    model_name="/app/model/model",
    temperature=0.7,
    enable_thinking="False"
)
response = model.send_request(req)
response.content
# Out:
# b'{"id":"chatcmpl-ef84f3e7327971cffabc52c65a060055","object":"chat.completion","created":1757325173,"model":"/app/model/model","choices":[{"index":0,"message":{"role":"assistant","reasoning_content":null,"content":"I am a large language model created by Alibaba Cloud. I\'m here to provide assistance and engage in conversation. How can I help you today?","tool_calls":[]},"logprobs":null,"finish_reason":"stop","stop_reason":null}],"usage":{"prompt_tokens":23,"total_tokens":53,"completion_tokens":30,"prompt_tokens_details":null},"prompt_logprobs":null,"kv_transfer_params":null}'

# %%
model = ModelClient(base_url= "https://millmchatqwen25-backend.dat-aip-millm.qa.mbcp.cloud/")
req = model.build_chat_request(
    user_prompt="Who are you?",
    system_prompt="",
    model_name="/app/model/model",
    temperature=0.7,
    enable_thinking="False"
)
response = model.send_request(req)
response.content
# Out:
# b'{"id":"chat-8dfc2667a24845708c14f660780b7448","object":"chat.completion","created":1757325192,"model":"/app/model/model","choices":[{"index":0,"message":{"role":"assistant","content":"I\'m a large language model created by Alibaba Cloud. I go by the name Qwen. How can I assist you today?","tool_calls":[]},"logprobs":null,"finish_reason":"stop","stop_reason":null}],"usage":{"prompt_tokens":23,"total_tokens":50,"completion_tokens":27},"prompt_logprobs":null}'

# %%
model = ModelClient(base_url= "https://millmchat-backend.dat-aip-millm.in.mbcp.cloud/")
req = model.build_chat_request(
    user_prompt="Who are you?",
    system_prompt="",
    model_name="/app/model/model",
    temperature=0.7,
    enable_thinking="False"
)
response = model.send_request(req)
response.content
# Out:
# b'{"id":"chatcmpl-4a47f86c391824cacde65dbe961f6bdf","object":"chat.completion","created":1756920110,"model":"/app/model/model","choices":[{"index":0,"message":{"role":"assistant","reasoning_content":null,"content":"I am LLaMA, an AI assistant developed by Meta AI that can understand and respond to human input in a conversational manner. I\'m not a human, but a computer program designed to simulate conversation and answer questions to the best of my ability based on my training data.\\n\\nI\'m a large language model, which means I\'ve been trained on a massive dataset of text from various sources, including books, articles, and websites. This training enables me to understand and generate human-like text, allowing me to converse with you about a wide range of topics.\\n\\nI\'m constantly learning and improving my abilities, so please bear with me if I make mistakes or don\'t quite grasp the nuances of human conversation. I\'m here to help and provide information, and I\'ll do my best 
# ...

# %%
model = ModelClient(base_url= "https://millmchatllama31-backend.dat-aip-millm.qa.mbcp.cloud/")
req = model.build_chat_request(
    user_prompt="Who are you?",
    system_prompt="",
    model_name="/app/model/model",
    temperature=0.7,
    enable_thinking="False"
)
response = model.send_request(req)
response.content
# Out:
# b'{"id":"chatcmpl-4d76f17b814d1f8a22b9f80428da557a","object":"chat.completion","created":1757325210,"model":"/app/model/model","choices":[{"index":0,"message":{"role":"assistant","reasoning_content":null,"content":"I\'m an artificial intelligence model known as Llama. Llama stands for \\"Large Language Model Meta AI.\\"","tool_calls":[]},"logprobs":null,"finish_reason":"stop","stop_reason":null}],"usage":{"prompt_tokens":14,"total_tokens":37,"completion_tokens":23,"prompt_tokens_details":null},"prompt_logprobs":null,"kv_transfer_params":null}'
